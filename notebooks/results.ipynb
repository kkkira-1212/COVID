# %% [markdown]
# <style>
# .notebook-content { font-size: 13px; }
# h1 { font-size: 20px; }
# h2 { font-size: 16px; }
# h3 { font-size: 14px; }
# table { font-size: 12px; }
# code { font-size: 11px; }
# </style>
#
# # Ablation Study: 6-Feature Dataset (Simplified)
#
# <div style="font-size: 13px;">
#
# ## 1. Baseline: Weekly Only
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.700526 |
# | F1 | 0.7925 |
# | Precision | 0.9000 |
# | Recall | 0.7079 |
# | AUPRC | 0.8820 |
# | ROC-AUC | 0.9637 |
#
# ---
#
# ## 2. Multi-Scale without L_u
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.538164 |
# | F1 | 0.8116 |
# | Precision | 0.7119 |
# | Recall | 0.9438 |
# | AUPRC | 0.9316 |
# | ROC-AUC | 0.9881 |
#
# ---
#
# ## 3. Multi-Scale with L_u (λ sensitivity)
#
# ### λ = 0.3
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.680728 |
# | F1 | 0.7451 |
# | Precision | 0.8906 |
# | Recall | 0.6404 |
# | AUPRC | 0.8480 |
# | ROC-AUC | 0.9454 |
#
# ### λ = 0.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.736913 |
# | F1 | 0.7582 |
# | Precision | 0.9062 |
# | Recall | 0.6517 |
# | AUPRC | 0.7962 |
# | ROC-AUC | 0.9065 |
#
# ### λ = 1.0 (Best)
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.606789 |
# | F1 | **0.8482** |
# | Precision | 0.7941 |
# | Recall | 0.9101 |
# | AUPRC | **0.9361** |
# | ROC-AUC | **0.9893** |
#
# ### λ = 1.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.767957 |
# | F1 | 0.7821 |
# | Precision | 0.9104 |
# | Recall | 0.6854 |
# | AUPRC | 0.8291 |
# | ROC-AUC | 0.9223 |
#
# ---
#
# ## 4. Multi-Scale with Post-processing
#
# **Model:** `ours_multiscale` (λ=1.0) with post-processing
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.703356 |
# | F1 | 0.8066 |
# | Precision | 0.7935 |
# | Recall | 0.8202 |
# | AUPRC | 0.8972 |
# | ROC-AUC | 0.9838 |
#
# </div>

# %% [markdown]
# # Ablation Study: 21-Feature Dataset (Full Features)
#
# <div style="font-size: 13px;">
#
# ## 1. Baseline: Weekly Only
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.825824 |
# | F1 | 0.6239 |
# | Precision | 0.7556 |
# | Recall | 0.5312 |
# | AUPRC | 0.5746 |
# | ROC-AUC | 0.6857 |
#
# ---
#
# ## 2. Multi-Scale without L_u
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.780038 |
# | F1 | 0.6087 |
# | Precision | 0.6863 |
# | Recall | 0.5469 |
# | AUPRC | 0.5788 |
# | ROC-AUC | 0.6885 |
#
# ---
#
# ## 3. Multi-Scale with L_u (λ sensitivity)
#
# ### λ = 0.3
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.819966 |
# | F1 | 0.6107 |
# | Precision | 0.5970 |
# | Recall | 0.6250 |
# | AUPRC | 0.7214 |
# | ROC-AUC | 0.9370 |
#
# ### λ = 0.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.509635 |
# | F1 | 0.5914 |
# | Precision | 0.4508 |
# | Recall | 0.8594 |
# | AUPRC | 0.7395 |
# | ROC-AUC | 0.9525 |
#
# ### λ = 1.0
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.733488 |
# | F1 | 0.6400 |
# | Precision | 0.6557 |
# | Recall | 0.6250 |
# | AUPRC | 0.6316 |
# | ROC-AUC | 0.7882 |
#
# ### λ = 1.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.565561 |
# | F1 | 0.5641 |
# | Precision | 0.4198 |
# | Recall | 0.8594 |
# | AUPRC | 0.7434 |
# | ROC-AUC | 0.9552 |
#
# </div>

# %% [markdown]
# # Baseline Models: 21-Feature Dataset
#
# <div style="font-size: 13px;">
#
# ## Forecasting-based Anomaly Detection (Weekly-level)
#
# ### PatchTST
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 1.122431 |
# | F1 | 0.5185 |
# | Precision | 0.6364 |
# | Recall | 0.4375 |
# | AUPRC | 0.5716 |
# | ROC-AUC | 0.7984 |
#
# ---
#
# ### DLINEAR
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 1.287725 |
# | F1 | 0.5263 |
# | Precision | 0.6000 |
# | Recall | 0.4688 |
# | AUPRC | 0.5521 |
# | ROC-AUC | 0.8767 |
#
# ---
#
# ### LSTM
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.719789 |
# | F1 | 0.6190 |
# | Precision | 0.6290 |
# | Recall | 0.6094 |
# | AUPRC | 0.6288 |
# | ROC-AUC | 0.7892 |
#
# ---
#
# ### AERCA
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.916063 |
# | F1 | 0.2929 |
# | Precision | 0.2164 |
# | Recall | 0.4531 |
# | AUPRC | 0.2417 |
# | ROC-AUC | 0.7408 |
#
# </div>

# %% [markdown]
# # NOT WORKING Additional Experimental Results
#
# <div style="font-size: 13px;">
#
# ## Normalized Residual Results
#
# ### PatchTST
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.560929 |
# | F1 | 0.3596 |
# | Precision | 0.2807 |
# | Recall | 0.5000 |
# | AUPRC | 0.3548 |
# | ROC-AUC | 0.6253 |
#
# ---
#
# ### DLINEAR
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.767594 |
# | F1 | 0.5827 |
# | Precision | 0.5873 |
# | Recall | 0.5781 |
# | AUPRC | 0.6441 |
# | ROC-AUC | 0.9298 |
#
# ---
#
# ### LSTM
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.457714 |
# | F1 | 0.6116 |
# | Precision | 0.6491 |
# | Recall | 0.5781 |
# | AUPRC | 0.6241 |
# | ROC-AUC | 0.7981 |
#
# ---
#
# ### OURS_MULTISCALE
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.579337 |
# | F1 | 0.6195 |
# | Precision | 0.7143 |
# | Recall | 0.5469 |
# | AUPRC | 0.5940 |
# | ROC-AUC | 0.7193 |
#
# </div>

# %% [markdown]
# 以下是基于ROC-AUC然后是6个精简特征，依然是标量情况下：
#
# OURS_WEEKONLY Results:
#   Threshold: 0.760781
#   F1:        0.7285
#   Precision: 0.8871
#   Recall:    0.6180
#   AUPRC:     0.7785
#   ROC-AUC:   0.8803
#
# L_u=0
#   OURS_MULTISCALE Results:
#   Threshold: 0.687792
#   F1:        0.7578
#   Precision: 0.8472
#   Recall:    0.6854
#   AUPRC:     0.7853
#   ROC-AUC:   0.8928
#
#
# OURS_MULTISCALE Results with L_u=1.0
#   Threshold: 0.521074
#   F1:        0.8400
#   Precision: 0.7568
#   Recall:    0.9438
#   AUPRC:     0.9307
#   ROC-AUC:   0.9873
#
#  L_u=0.3
#  OURS_MULTISCALE Results:
#   Threshold: 0.730727
#   F1:        0.7949
#   Precision: 0.9254
#   Recall:    0.6966
#   AUPRC:     0.8559
#   ROC-AUC:   0.9441
#
#
# L_u=0.5
#  Threshold: 0.542721
#   F1:        0.8235
#   Precision: 0.7304
#   Recall:    0.9438
#   AUPRC:     0.9340
#   ROC-AUC:   0.9884
#
#
# L_u=1.5
# OURS_MULTISCALE Results:
#   Threshold: 0.687921
#   F1:        0.8398
#   Precision: 0.8261
#   Recall:    0.8539
#   AUPRC:     0.9397
#   ROC-AUC:   0.9899

# %% [markdown]
# PATCHTST Results:
#   Threshold: 0.579380
#   F1:        0.7921
#   Precision: 0.7080
#   Recall:    0.8989
#   AUPRC:     0.8671
#   ROC-AUC:   0.9797
#
# DLINEAR Results:
#   Threshold: 0.955861
#   F1:        0.6923
#   Precision: 0.5586
#   Recall:    0.9101
#   AUPRC:     0.6684
#   ROC-AUC:   0.9524
#
#
# LSTM Results:
#   Threshold: 0.569024
#   F1:        0.8063
#   Precision: 0.7549
#   Recall:    0.8652
#   AUPRC:     0.9010
#   ROC-AUC:   0.9727
#
#
# AERCA Results:
#   Threshold: 0.697299
#   F1:        0.4800
#   Precision: 0.3971
#   Recall:    0.6067
#   AUPRC:     0.3380
#   ROC-AUC:   0.7970

# %% [markdown]
# 21features：
# OURS_MULTISCALE Results with L_U=1.0
#   Threshold: 0.904838
#   F1:        0.6504
#   Precision: 0.6780
#   Recall:    0.6250
#   AUPRC:     0.7187
#   ROC-AUC:   0.9341
#
#  OURS_MULTISCALE Results:
#   Threshold: 0.818905
#   F1:        0.6269
#   Precision: 0.6000
#   Recall:    0.6562
#   AUPRC:     0.7371
#   ROC-AUC:   0.9501
#
# OURS_MULTISCALE Results:
#   Threshold: 0.491796
#   F1:        0.5778
#   Precision: 0.4483
#   Recall:    0.8125
#   AUPRC:     0.7295
#   ROC-AUC:   0.9444
#
# =======================
# L_u=0.0
# OURS_MULTISCALE Results:
#   Threshold: 0.769730
#   F1:        0.6667
#   Precision: 0.7143
#   Recall:    0.6250
#   AUPRC:     0.6261
#   ROC-AUC:   0.7803
#
# L_u=0.3
# OURS_MULTISCALE Results:
#   Threshold: 0.841159
#   F1:        0.6724
#   Precision: 0.7500
#   Recall:    0.6094
#   AUPRC:     0.6454
#   ROC-AUC:   0.8176
#
# L_u=0.5
# OURS_MULTISCALE Results:
#   Threshold: 0.788403
#   F1:        0.6612
#   Precision: 0.7018
#   Recall:    0.6250
#   AUPRC:     0.6739
#   ROC-AUC:   0.8614
#
#
# L_u=1.5
# OURS_MULTISCALE Results:
#   Threshold: 0.489092
#   F1:        0.5833
#   Precision: 0.4375
#   Recall:    0.8750
#   AUPRC:     0.7452
#   ROC-AUC:   0.9546
#
# OURS_MULTISCALE Results:
#   Threshold: 0.811717
#   F1:        0.6435
#   Precision: 0.7255
#   Recall:    0.5781
#   AUPRC:     0.6047
#   ROC-AUC:   0.7139
#
# OURS_MULTISCALE Results:
#   Threshold: 0.886638
#   F1:        0.6504
#   Precision: 0.6780
#   Recall:    0.6250
#   AUPRC:     0.7098
#   ROC-AUC:   0.9219

# %% [markdown]
# 21features：
#
# PATCHTST Results:
#   Threshold: 0.990372
#   F1:        0.6016
#   Precision: 0.6271
#   Recall:    0.5781
#   AUPRC:     0.6979
#   ROC-AUC:   0.9338
#
#
# DLINEAR Results:
#   Threshold: 1.037411
#   F1:        0.4553
#   Precision: 0.4746
#   Recall:    0.4375
#   AUPRC:     0.4702
#   ROC-AUC:   0.7230
#
#
# LSTM Results:
#   Threshold: 0.824488
#   F1:        0.6107
#   Precision: 0.5970
#   Recall:    0.6250
#   AUPRC:     0.7089
#   ROC-AUC:   0.9242
#
#
# AERCA Results:
#   Threshold: 1.223903
#   F1:        0.3089
#   Precision: 0.2088
#   Recall:    0.5938
#   AUPRC:     0.2219
#   ROC-AUC:   0.7079
