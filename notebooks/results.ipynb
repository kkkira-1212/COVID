# %% [markdown]
# <style>
# .notebook-content { font-size: 13px; }
# h1 { font-size: 20px; }
# h2 { font-size: 16px; }
# h3 { font-size: 14px; }
# table { font-size: 12px; }
# code { font-size: 11px; }
# </style>
#
# # Ablation Study: 6-Feature Dataset (Simplified)
#
# <div style="font-size: 13px;">
#
# ## 1. Baseline: Weekly Only
#
# **Model:** `ours_weekonly` (weekly_only=True, use_lu=False)
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.700526 |
# | F1 | 0.7925 |
# | Precision | 0.9000 |
# | Recall | 0.7079 |
# | AUPRC | 0.8820 |
# | ROC-AUC | 0.9637 |
#
# ---
#
# ## 2. Multi-Scale without L_u
#
# **Model:** `ours_multiscale_no_lu` (weekly_only=False, use_lu=False)
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.538164 |
# | F1 | 0.8116 |
# | Precision | 0.7119 |
# | Recall | 0.9438 |
# | AUPRC | 0.9316 |
# | ROC-AUC | 0.9881 |
#
# ---
#
# ## 3. Multi-Scale with L_u (λ sensitivity)
#
# ### λ = 0.3
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.680728 |
# | F1 | 0.7451 |
# | Precision | 0.8906 |
# | Recall | 0.6404 |
# | AUPRC | 0.8480 |
# | ROC-AUC | 0.9454 |
#
# ### λ = 0.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.736913 |
# | F1 | 0.7582 |
# | Precision | 0.9062 |
# | Recall | 0.6517 |
# | AUPRC | 0.7962 |
# | ROC-AUC | 0.9065 |
#
# ### λ = 1.0 ⭐ (Best)
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.606789 |
# | F1 | **0.8482** |
# | Precision | 0.7941 |
# | Recall | 0.9101 |
# | AUPRC | **0.9361** |
# | ROC-AUC | **0.9893** |
#
# ### λ = 1.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.767957 |
# | F1 | 0.7821 |
# | Precision | 0.9104 |
# | Recall | 0.6854 |
# | AUPRC | 0.8291 |
# | ROC-AUC | 0.9223 |
#
# ---
#
# ## 4. Multi-Scale with Post-processing
#
# **Model:** `ours_multiscale` (λ=1.0) with post-processing
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.703356 |
# | F1 | 0.8066 |
# | Precision | 0.7935 |
# | Recall | 0.8202 |
# | AUPRC | 0.8972 |
# | ROC-AUC | 0.9838 |
#
# </div>

# %% [markdown]
# # Baseline Models: 6-Feature Dataset
#
# <div style="font-size: 13px;">
#
# ## Forecasting-based Anomaly Detection (Weekly-level)
#
# ### DLINEAR
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.794387 |
# | F1 | 0.7719 |
# | Precision | 0.8049 |
# | Recall | 0.7416 |
# | AUPRC | 0.7511 |
# | ROC-AUC | 0.9554 |
#
# ---
#
# ### LSTM
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.737223 |
# | F1 | 0.8293 |
# | Precision | 0.9067 |
# | Recall | 0.7640 |
# | AUPRC | 0.9095 |
# | ROC-AUC | 0.9766 |
#
# ---
#
# ### PatchTST
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.523299 |
# | F1 | 0.7926 |
# | Precision | 0.6719 |
# | Recall | 0.9663 |
# | AUPRC | 0.8516 |
# | ROC-AUC | 0.9807 |
#
# ---
#
# ### AERCA
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.864065 |
# | F1 | 0.5502 |
# | Precision | 0.4111 |
# | Recall | 0.8315 |
# | AUPRC | 0.3865 |
# | ROC-AUC | 0.8546 |
#
# </div>

# %% [markdown]
# # Ablation Study: 21-Feature Dataset (Full Features)
#
# <div style="font-size: 13px;">
#
# ## 1. Baseline: Weekly Only
#
# **Model:** `ours_weekonly`
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.825824 |
# | F1 | 0.6239 |
# | Precision | 0.7556 |
# | Recall | 0.5312 |
# | AUPRC | 0.5746 |
# | ROC-AUC | 0.6857 |
#
# ---
#
# ## 2. Multi-Scale without L_u
#
# **Model:** `ours_multiscale_no_lu`
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.780038 |
# | F1 | 0.6087 |
# | Precision | 0.6863 |
# | Recall | 0.5469 |
# | AUPRC | 0.5788 |
# | ROC-AUC | 0.6885 |
#
# ---
#
# ## 3. Multi-Scale with L_u (λ sensitivity)
#
# ### λ = 0.3
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.819966 |
# | F1 | 0.6107 |
# | Precision | 0.5970 |
# | Recall | 0.6250 |
# | AUPRC | 0.7214 |
# | ROC-AUC | 0.9370 |
#
# ### λ = 0.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.509635 |
# | F1 | 0.5914 |
# | Precision | 0.4508 |
# | Recall | 0.8594 |
# | AUPRC | 0.7395 |
# | ROC-AUC | 0.9525 |
#
# ### λ = 1.0
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.733488 |
# | F1 | 0.6400 |
# | Precision | 0.6557 |
# | Recall | 0.6250 |
# | AUPRC | 0.6316 |
# | ROC-AUC | 0.7882 |
#
# ### λ = 1.5
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.565561 |
# | F1 | 0.5641 |
# | Precision | 0.4198 |
# | Recall | 0.8594 |
# | AUPRC | 0.7434 |
# | ROC-AUC | 0.9552 |
#
# </div>

# %% [markdown]
# # Baseline Models: 21-Feature Dataset
#
# <div style="font-size: 13px;">
#
# ## Forecasting-based Anomaly Detection (Weekly-level)
#
# ### PatchTST
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 1.122431 |
# | F1 | 0.5185 |
# | Precision | 0.6364 |
# | Recall | 0.4375 |
# | AUPRC | 0.5716 |
# | ROC-AUC | 0.7984 |
#
# ---
#
# ### DLINEAR
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 1.287725 |
# | F1 | 0.5263 |
# | Precision | 0.6000 |
# | Recall | 0.4688 |
# | AUPRC | 0.5521 |
# | ROC-AUC | 0.8767 |
#
# ---
#
# ### LSTM
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.719789 |
# | F1 | 0.6190 |
# | Precision | 0.6290 |
# | Recall | 0.6094 |
# | AUPRC | 0.6288 |
# | ROC-AUC | 0.7892 |
#
# ---
#
# ### AERCA
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.916063 |
# | F1 | 0.2929 |
# | Precision | 0.2164 |
# | Recall | 0.4531 |
# | AUPRC | 0.2417 |
# | ROC-AUC | 0.7408 |
#
# </div>

# %% [markdown]
# # Additional Experimental Results
#
# <div style="font-size: 13px;">
#
# ## Normalized Residual Results
#
# ### PatchTST
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.560929 |
# | F1 | 0.3596 |
# | Precision | 0.2807 |
# | Recall | 0.5000 |
# | AUPRC | 0.3548 |
# | ROC-AUC | 0.6253 |
#
# ---
#
# ### DLINEAR
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.767594 |
# | F1 | 0.5827 |
# | Precision | 0.5873 |
# | Recall | 0.5781 |
# | AUPRC | 0.6441 |
# | ROC-AUC | 0.9298 |
#
# ---
#
# ### LSTM
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.457714 |
# | F1 | 0.6116 |
# | Precision | 0.6491 |
# | Recall | 0.5781 |
# | AUPRC | 0.6241 |
# | ROC-AUC | 0.7981 |
#
# ---
#
# ### OURS_MULTISCALE
#
# | Metric | Value |
# |--------|-------|
# | Threshold | 0.579337 |
# | F1 | 0.6195 |
# | Precision | 0.7143 |
# | Recall | 0.5469 |
# | AUPRC | 0.5940 |
# | ROC-AUC | 0.7193 |
#
# </div>
